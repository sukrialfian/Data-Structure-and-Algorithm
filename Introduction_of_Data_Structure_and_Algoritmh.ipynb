# %% [markdown]
# Definition : Data Structure are building blocks or any raw materials of all software programs. The application of data structure depends on its case.![Screenshot 2024-05-16 151349.png](data:image/png;base64,...)

# %% [markdown]
# From the above case, we can apply a method based on the issue we encounter. For example, if the data is provided in list format, we can use the array method. If the data is provided in dictionary format, we can utilize dictionary keys.
